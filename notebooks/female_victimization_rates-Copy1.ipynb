# %%
import pandas as pd

# %%
female_victimization_rates_df= pd.read_csv('female-victim-rates.csv')

# %%
#edited the formatting of the original .csv file using TextEdit

# %%
female_victimization_rates_df.head(17)
# Out:
#     Year    Total  Rate Completed  Rate.1 Attempted  Rate.2 Threatened  Rate.3
# 0   1995  555,600   5.0   402,000     3.6    83,900     0.8     69,800     0.6
# 1   1996  443,300   4.0   304,300     2.7    56,400     0.5     82,600     0.7
# 2   1997  450,100   4.0   301,400     2.7    55,200     0.5     93,500     0.8
# 3   1998  436,400   3.8   322,100     2.8    62,600     0.5     51,700     0.5
# 4   1999  458,900   4.0   346,000     3.0    82,300     0.7     30,600     0.3
# 5   2000  452,100   3.9   352,200     3.0    71,300     0.6     28,600     0.2
# 6   2001  390,700   3.3   286,400     2.4    67,400     0.6     36,800     0.3
# 7   2002  366,200   3.1   244,100     2.1    70,700     0.6     51,400     0.4
# 8   2003  304,300   2.5   212,200     1.7    57,900     0.5     34,200     0.3
# 9   2004  277,600   2.2   204,500     1.7    55,000     0.4     18,000     0.1
# 10  2005  221,100   1.8   158,700     1.3    42,900     0.3     19,500     0.2
# ...

# %%
female_victimization_rates_df.plot.scatter(y='Rate', x='Year')
title= 'Total'

# %%
female_victimization_rates_df.plot.scatter(y='Rate.1', x='Year')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Rate.1'>

# %%
female_victimization_rates_df.plot.scatter(y='Rate.2', x='Year')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Rate.2'>

# %%
female_victimization_rates_df.plot.scatter(y='Rate.2', x='Year')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Rate.2'>

# %%
female_victimization_rates_df.plot.line(
    x='Year', y='Rate', 
    color='red',
    title='Total',
    xlabel='Year',
    ylabel='Rate')
# Out:
# <AxesSubplot:title={'center':'Total'}, xlabel='Year', ylabel='Rate'>

# %%
female_victimization_rates_df.plot.line(
    x='Year', y='Rate.1', 
    color='orange',
    title='Completed',
    xlabel='Year',
    ylabel='Rate')
# Out:
# <AxesSubplot:title={'center':'Completed'}, xlabel='Year', ylabel='Rate'>

# %%
female_victimization_rates_df.plot.line(
    x='Year', y='Rate.2', 
    color='green',
    title='Attempted',
    xlabel='Year',
    ylabel='Rate')
# Out:
# <AxesSubplot:title={'center':'Attempted'}, xlabel='Year', ylabel='Rate'>

# %%
female_victimization_rates_df.plot.line(
    x='Year', y='Rate.3', 
    color='blue',
    title='Threatened',
    xlabel='Year',
    ylabel='Rate')
# Out:
# <AxesSubplot:title={'center':'Threatened'}, xlabel='Year', ylabel='Rate'>

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from pandas.core.frame import DataFrame
from random import shuffle
import seaborn as sns

# %%
sns.pairplot(female_victimization_rates_df)
