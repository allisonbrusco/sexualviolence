# %%
import pandas as pd

# %%
victims_by_sex_df=pd.read_csv('victims-by-sex.csv')

# %%
#edited the formatting of the original .csv file using TextEdit

# %%
victims_by_sex_df.head(17)
# Out:
#     Year All persons  rate   Female  rate.1    Male  rate.2
# 0   1995     618,800   2.9  555,600     5.0  63,100     0.6
# 1   1996     500,200   2.3  443,300     4.0  56,900     0.5
# 2   1997     495,400   2.3  450,100     4.0  45,200     0.4
# 3   1998     472,300   2.1  436,400     3.8  35,900     0.3
# 4   1999     491,300   2.2  458,900     4.0  32,400     0.3
# 5   2000     479,100   2.1  452,100     3.9  27,100     0.2
# 6   2001     421,700   1.8  390,700     3.3  31,000     0.3
# 7   2002     413,200   1.8  366,200     3.1  47,000     0.4
# 8   2003     337,600   1.4  304,300     2.5  33,300     0.3
# 9   2004     290,500   1.2  277,600     2.2  12,900     0.1
# 10  2005     231,800   1.0  221,100     1.8  10,600     0.1
# 11  2006     335,700   1.4  276,300     2.2  59,400     0.5
# 12  2007     355,900   1.4  298,400     2.3  57,500     0.5
# 13  2008     299,000   1.2  273,500     2.1  25,400     0.2
# 14  2009     327,600   1.3  297,900     2.3  29,700     0.2
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=[1995, 1996, 1997, 1998, 1999, 2000, 2001, 2001, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010]
y1= [5, 4, 4, 3.8, 4, 3.9, 3.3, 3.1, 2.5, 2.2, 1.8, 2.2, 2.3, 2.1, 2.3, 2.1]
y2= [.6, .5, .4, .3, .3, .2, .3, .4, .3, .1, .1, .5, .5, .2, .2, .1]

# %%
plt.plot(x, y1, label = "Females")
plt.plot(x, y2, label = "Males")
plt.title('Rates of Sexual Violence among Men vs Women,  1995-2010')
plt.xlabel('Year')
plt.ylabel('Rate')
plt.legend()
plt.show()
