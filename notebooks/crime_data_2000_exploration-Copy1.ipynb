# %%
import pandas as pd

# %%
crime_2000_df=pd.read_csv('crime_data_2000.tsv', sep='\t')

# %%
crime_2000_df.head()
# Out:
#    ASR_ID  CONTENTS  STATE      ORI GROUP  DIV  YEAR  MSA  SUB  REPORT  ...  \
# 0       3         2     50  AK00101    1C    9  2000   37    0       0  ...
# 1       3         2     50  AK00101    1C    9  2000   37    0       0  ...
# 2       3         2     50  AK00101    1C    9  2000   37    0       0  ...
# 3       3         2     50  AK00101    1C    9  2000   37    0       0  ...
# 4       3         2     50  AK00101    1C    9  2000   37    0       0  ...
#
#    JI  JA  JH JN   AW  AB  AI  AA  AH  AN
# 0   0   0   0  0    4   4   2   1   0   0
# 1   0   2   0  0    3   0   0   1   0   0
# 2   2   0   0  0    7   1   7   1   0   0
# 3   3   8   0  0   23  19   7   2   0   0
# 4  18   4   0  0  138  47  61  15   0   0
#
# [5 rows x 78 columns]

# %%
del crime_2000_df["ASR_ID"]
del crime_2000_df["CONTENTS"]
del crime_2000_df["STATE"]
del crime_2000_df["ORI"]
del crime_2000_df["YEAR"]
del crime_2000_df["MSA"]
del crime_2000_df["SUB"]
del crime_2000_df["REPORT"]
del crime_2000_df["ADJUST"]
del crime_2000_df["SEQNO"]
del crime_2000_df["COUNTY"]
del crime_2000_df["POP"]
del crime_2000_df["AGENCNT"]
del crime_2000_df["AGENCY"]
del crime_2000_df["CARD1"]
del crime_2000_df["CARD2"]
del crime_2000_df["CARD3"]

# %%
sexual_violence_US= crime_2000_df[(crime_2000_df['OFFENSE'] == 170) | (crime_2000_df['OFFENSE'] == 20)]
sexual_violence_US
#grouped together by offence codes regarding all sexual violence
# Out:
#        GROUP  DIV CORE  STNAME  OFFENSE  M0_9  M10_12  M13_14  M15  M16  ...  \
# 2         1C    9    N  ALASKA       20     0       0       1    1    0  ...
# 15        1C    9    N  ALASKA      170     0       0       5    2    0  ...
# 33         4    9    N  ALASKA       20     0       0       1    0    0  ...
# 47         4    9    N  ALASKA      170     0       0       1    0    1  ...
# 75         6    9    N  ALASKA      170     0       0       0    0    0  ...
# ...      ...  ...  ...     ...      ...   ...     ...     ...  ...  ...  ...
# 232227    8D    8    N     WYO      170     0       0       1    0    0  ...
# 232246     5    8    N     WYO      170     0       0       0    0    1  ...
# 232267     7    8    N     WYO      170     0       0       0    0    0  ...
# 232284    8D    8    N     WYO      170     0       0       0    0    0  ...
# 232309     6    8    N     WYO      170     0       0       0    0    0  ...
#
# ...

# %%
male_perpetrators = sexual_violence_US.eval('Male_Sum = M0_9 + M10_12 + M13_14 + M15 + M16 + M17 + M18 + M19 + M20 + M21 + M22 + M23 + M24 + M25_29 + M30_34 + M35_39 + M40_44 + M45_49 + M50_54 + M55_59 + M60_64 + M65')
print(male_perpetrators)
# Out:
#        GROUP  DIV CORE  STNAME  OFFENSE  M0_9  M10_12  M13_14  M15  M16  ...  \
# 2         1C    9    N  ALASKA       20     0       0       1    1    0  ...
# 15        1C    9    N  ALASKA      170     0       0       5    2    0  ...
# 33         4    9    N  ALASKA       20     0       0       1    0    0  ...
# 47         4    9    N  ALASKA      170     0       0       1    0    1  ...
# 75         6    9    N  ALASKA      170     0       0       0    0    0  ...
# ...      ...  ...  ...     ...      ...   ...     ...     ...  ...  ...  ...
# 232227    8D    8    N     WYO      170     0       0       1    0    0  ...
# 232246     5    8    N     WYO      170     0       0       0    0    1  ...
# 232267     7    8    N     WYO      170     0       0       0    0    0  ...
# 232284    8D    8    N     WYO      170     0       0       0    0    0  ...
# 232309     6    8    N     WYO      170     0       0       0    0    0  ...
#
# ...

# %%
column_name = "Male_Sum"
column_sum = male_perpetrators[column_name].sum()
column_sum
# Out:
# 91300

# %%
female_perpetrators = sexual_violence_US.eval('Female_Sum = F0_9 + F10_12 + F13_14 + F15 + F16 + F17 + F18 + F19 + F20 + F21 + F22 + F23 + F24 + F25_29 + F30_34 + F35_39 + F40_44 + F45_49 + F50_54 + F55_59 + F60_64 + F65')
print(female_perpetrators)
# Out:
#        GROUP  DIV CORE  STNAME  OFFENSE  M0_9  M10_12  M13_14  M15  M16  ...  \
# 2         1C    9    N  ALASKA       20     0       0       1    1    0  ...
# 15        1C    9    N  ALASKA      170     0       0       5    2    0  ...
# 33         4    9    N  ALASKA       20     0       0       1    0    0  ...
# 47         4    9    N  ALASKA      170     0       0       1    0    1  ...
# 75         6    9    N  ALASKA      170     0       0       0    0    0  ...
# ...      ...  ...  ...     ...      ...   ...     ...     ...  ...  ...  ...
# 232227    8D    8    N     WYO      170     0       0       1    0    0  ...
# 232246     5    8    N     WYO      170     0       0       0    0    1  ...
# 232267     7    8    N     WYO      170     0       0       0    0    0  ...
# 232284    8D    8    N     WYO      170     0       0       0    0    0  ...
# 232309     6    8    N     WYO      170     0       0       0    0    0  ...
#
# ...

# %%
column_name = "Female_Sum"
column_sum = female_perpetrators[column_name].sum()
column_sum
# Out:
# 5579

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
male_perpetrators_gb = male_perpetrators.groupby('STNAME', as_index=False).sum()
display(male_perpetrators_gb)
# Out:
#     STNAME   DIV  OFFENSE  M0_9  M10_12  M13_14  M15  M16  M17  M18  ...  JA  \
# 0      ALA   996    15470     0       6      12   15   11   13   31  ...   0
# 1   ALASKA   234     3370     5       7      17   14   10   11   14  ...   1
# 2     ARIZ   880    13600     3      39     106   63   50   53   50  ...   1
# 3      ARK  1421    20560     4      13      26   24   27   30   49  ...   1
# 4    CALIF  8172    99310    69     294     840  485  501  515  568  ...  41
# 5     COLO  1384    18610     1      74     161   66   56   46   65  ...   2
# 6     CONN   124    14630    14      45      78   35   33   44   48  ...   1
# 7      DEL   255     5370     1      23      53   29   20   17   28  ...   0
# 8       GA  1895    44330    12      78     158   96   98  145  165  ...   2
# 9   HAWAII    72      760     1      20      52   23   12    7    8  ...  87
# 10   IDAHO   896    12890     4      26      42   26   16   26   21  ...   1
# ...

# %%
states = {
        'ALA': 'Alabama',
        'ALASKA': 'Alaska',
        'ARK': 'Arkansas',
        'ARIZ': 'Arizona',
        'CALIF': 'California',
        'COLO': 'Colorado',
        'CONN': 'Connecticut',
        'D C': 'District of Columbia',
        'DEL': 'Delaware',
        'HAWAII': 'Hawaii',
        'GA': 'Georgia',
        'ILL': 'Illinois',
        'IDAHO': 'Idaho',
        'IND': 'Indiana',
        'IOWA': 'Iowa',
        'KANS': 'Kansas',
        'KY': 'Kentucky',
        'LA': 'Louisiana',
        'MAINE': 'Maine',
        'MASS': 'Massachusetts',
        'MD': 'Maryland',
        'MICH': 'Michigan',
        'MINN': 'Minnesota',
        'MISS': 'Mississippi',
        'MO': 'Missouri',
        'MONT': 'Montana',
        'N C': 'North Carolina',
        'N DAK': 'North Dakota',
        'N H': 'New Hampshire',
        'N J': 'New Jersey',
        'N MEX': 'New Mexico',
        'N Y': 'New York',
        'NEBR': 'Nebraska',
        'NEV': 'Nevada',
        'OKLA': 'Oklahoma',
        'OHIO': 'Ohio',
        'OREG': 'Oregon',
        'PA': 'Pennsylvania',
        'R I': 'Rhode Island',
        'S C': 'South Carolina',
        'S DAK': 'South Dakota',
        'TENN': 'Tennessee',
        'TEXAS': 'Texas',
        'VA': 'Virginia',
        'VT': 'Vermont',
        'W VA': 'West Virginia',
        'UTAH': 'Utah',
        'WASH': 'Washington',
        'WIS': 'Wisonsin',
        'WYO': 'Wyoming'}

# %%
male_perpetrators_gb['STNAME'] = male_perpetrators_gb['STNAME'].replace(states)
male_perpetrators_gb.head()
# Out:
#        STNAME   DIV  OFFENSE  M0_9  M10_12  M13_14  M15  M16  M17  M18  ...  \
# 0     Alabama   996    15470     0       6      12   15   11   13   31  ...
# 1      Alaska   234     3370     5       7      17   14   10   11   14  ...
# 2     Arizona   880    13600     3      39     106   63   50   53   50  ...
# 3    Arkansas  1421    20560     4      13      26   24   27   30   49  ...
# 4  California  8172    99310    69     294     840  485  501  515  568  ...
#
#    JA  JH  JN     AW    AB   AI   AA  AH  AN  Male_Sum
# 0   0   0   0    361   239    1    0   0   0       646
# 1   1   0   0     95     9  139    3   0   0       309
# 2   1   0   0   1488   122  185    8   0   0      1998
# 3   1   0   0    677   255    4    2   0   0      1033
# 4  41   0   0  12400  2410  106  221   0   0     16944
#
# [5 rows x 60 columns]

# %%
male_perpetrators_gb.plot.bar(x='STNAME', y='Male_Sum')
# Out:
# <AxesSubplot:xlabel='STNAME'>

# %%
female_perpetrators_gb = female_perpetrators.groupby('STNAME', as_index=False).sum()
display(female_perpetrators_gb)
# Out:
#     STNAME   DIV  OFFENSE  M0_9  M10_12  M13_14  M15  M16  M17  M18  ...  JA  \
# 0      ALA   996    15470     0       6      12   15   11   13   31  ...   0
# 1   ALASKA   234     3370     5       7      17   14   10   11   14  ...   1
# 2     ARIZ   880    13600     3      39     106   63   50   53   50  ...   1
# 3      ARK  1421    20560     4      13      26   24   27   30   49  ...   1
# 4    CALIF  8172    99310    69     294     840  485  501  515  568  ...  41
# 5     COLO  1384    18610     1      74     161   66   56   46   65  ...   2
# 6     CONN   124    14630    14      45      78   35   33   44   48  ...   1
# 7      DEL   255     5370     1      23      53   29   20   17   28  ...   0
# 8       GA  1895    44330    12      78     158   96   98  145  165  ...   2
# 9   HAWAII    72      760     1      20      52   23   12    7    8  ...  87
# 10   IDAHO   896    12890     4      26      42   26   16   26   21  ...   1
# ...

# %%
states = {
        'ALA': 'Alabama',
        'ALASKA': 'Alaska',
        'ARK': 'Arkansas',
        'ARIZ': 'Arizona',
        'CALIF': 'California',
        'COLO': 'Colorado',
        'CONN': 'Connecticut',
        'D C': 'District of Columbia',
        'DEL': 'Delaware',
        'HAWAII': 'Hawaii',
        'GA': 'Georgia',
        'ILL': 'Illinois',
        'IDAHO': 'Idaho',
        'IND': 'Indiana',
        'IOWA': 'Iowa',
        'KANS': 'Kansas',
        'KY': 'Kentucky',
        'LA': 'Louisiana',
        'MAINE': 'Maine',
        'MASS': 'Massachusetts',
        'MD': 'Maryland',
        'MICH': 'Michigan',
        'MINN': 'Minnesota',
        'MISS': 'Mississippi',
        'MO': 'Missouri',
        'MONT': 'Montana',
        'N C': 'North Carolina',
        'N DAK': 'North Dakota',
        'N H': 'New Hampshire',
        'N J': 'New Jersey',
        'N MEX': 'New Mexico',
        'N Y': 'New York',
        'NEBR': 'Nebraska',
        'NEV': 'Nevada',
        'OKLA': 'Oklahoma',
        'OHIO': 'Ohio',
        'OREG': 'Oregon',
        'PA': 'Pennsylvania',
        'R I': 'Rhode Island',
        'S C': 'South Carolina',
        'S DAK': 'South Dakota',
        'TENN': 'Tennessee',
        'TEXAS': 'Texas',
        'VA': 'Virginia',
        'VT': 'Vermont',
        'W VA': 'West Virginia',
        'UTAH': 'Utah',
        'WASH': 'Washington',
        'WIS': 'Wisonsin',
        'WYO': 'Wyoming'}

# %%
female_perpetrators_gb['STNAME'] = female_perpetrators_gb['STNAME'].replace(states)
female_perpetrators_gb.head()
# Out:
#        STNAME   DIV  OFFENSE  M0_9  M10_12  M13_14  M15  M16  M17  M18  ...  \
# 0     Alabama   996    15470     0       6      12   15   11   13   31  ...
# 1      Alaska   234     3370     5       7      17   14   10   11   14  ...
# 2     Arizona   880    13600     3      39     106   63   50   53   50  ...
# 3    Arkansas  1421    20560     4      13      26   24   27   30   49  ...
# 4  California  8172    99310    69     294     840  485  501  515  568  ...
#
#    JA  JH  JN     AW    AB   AI   AA  AH  AN  Female_Sum
# 0   0   0   0    361   239    1    0   0   0          17
# 1   1   0   0     95     9  139    3   0   0           2
# 2   1   0   0   1488   122  185    8   0   0         142
# 3   1   0   0    677   255    4    2   0   0          38
# 4  41   0   0  12400  2410  106  221   0   0        1129
#
# [5 rows x 60 columns]

# %%
female_perpetrators_gb.plot.bar(x='STNAME', y='Female_Sum')
# Out:
# <AxesSubplot:xlabel='STNAME'>
