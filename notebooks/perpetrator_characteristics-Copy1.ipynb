# %%
import pandas as pd

# %%
perpetrator_charcteristics_df=pd.read_csv('perpetrator-characteristics.csv')

# %%
#edited the formatting of the original .csv file using TextEdit

# %%
perpetrator_charcteristics_df.head(20)
# Out:
#                           Characteristic  1994 to 1998 rates  \
# 0                                    Age                 100
# 1                          17 or younger                  12
# 2                               10 to 20                   9
# 3                               21 to 29                  24
# 4                            30 or older                  51
# 5                                  Other                   3
# 6                                   Race                 100
# 7                                  White                  70
# 8                                  Black                  18
# 9                                  Other                   8
# 10                           Mixed group                   1
# 11                               Unknown                   2
# 12  Alcohol/drug use at time of incident                 100
# 13                                   Yes                  40
# ...
