# %%
import pandas as pd

# %%
crime_2005_df=pd.read_csv('04716-0001-Data.tsv', sep='\t')

# %%
crime_2005_df.head()
# Out:
#    ASR_ID  CONTENTS  STATE      ORI GROUP  DIV  YEAR  MSA  SUB  REPORT  ...  \
# 0       3         2     50  AK00101    1C    9  2005   38    0       0  ...
# 1       3         2     50  AK00101    1C    9  2005   38    0       0  ...
# 2       3         2     50  AK00101    1C    9  2005   38    0       0  ...
# 3       3         2     50  AK00101    1C    9  2005   38    0       0  ...
# 4       3         2     50  AK00101    1C    9  2005   38    0       0  ...
#
#    JI  JA  JH JN   AW   AB   AI  AA  AH  AN
# 0   0   0   0  0    7    2    0   1   0   0
# 1   0   0   0  0    7    3    4   1   0   0
# 2   2   0   0  0   32   23   13   2   0   0
# 3  11  10   0  0  248  122  113  43   0   0
# 4   9  13   0  0   70   12   14   1   0   0
#
# [5 rows x 78 columns]

# %%
del crime_2005_df["ASR_ID"]
del crime_2005_df["CONTENTS"]
del crime_2005_df["STATE"]
del crime_2005_df["ORI"]
del crime_2005_df["YEAR"]
del crime_2005_df["MSA"]
del crime_2005_df["SUB"]
del crime_2005_df["REPORT"]
del crime_2005_df["ADJUST"]
del crime_2005_df["SEQNO"]
del crime_2005_df["COUNTY"]
del crime_2005_df["POP"]
del crime_2005_df["AGENCNT"]
del crime_2005_df["AGENCY"]
del crime_2005_df["CARD1"]
del crime_2005_df["CARD2"]
del crime_2005_df["CARD3"]

# %%
sexual_violence_US= crime_2005_df[(crime_2005_df['OFFENSE'] == 170) | (crime_2005_df['OFFENSE'] == 20)]
sexual_violence_US
#grouped together by offence codes regarding all sexual violence
# Out:
#        GROUP  DIV CORE  STNAME  OFFENSE  M0_9  M10_12  M13_14  M15  M16  ...  \
# 1         1C    9    Y  ALASKA       20     0       0       0    1    0  ...
# 15        1C    9    Y  ALASKA      170     0       1       3    0    2  ...
# 33         4    9    Y  ALASKA       20     0       0       3    1    0  ...
# 47         4    9    Y  ALASKA      170     0       0       0    0    0  ...
# 63         4    9    N  ALASKA       20     0       0       1    0    0  ...
# ...      ...  ...  ...     ...      ...   ...     ...     ...  ...  ...  ...
# 259176    8C    8    N     WYO      170     0       0       0    0    0  ...
# 259192     6    8    N     WYO       20     0       0       0    0    0  ...
# 259203     6    8    N     WYO      170     0       0       0    0    0  ...
# 259227    8D    8    N     WYO      170     0       0       0    0    0  ...
# 259250     5    8    N     WYO      170     0       0       0    0    0  ...
#
# ...

# %%
male_perpetrators = sexual_violence_US.eval('Male_Sum = M0_9 + M10_12 + M13_14 + M15 + M16 + M17 + M18 + M19 + M20 + M21 + M22 + M23 + M24 + M25_29 + M30_34 + M35_39 + M40_44 + M45_49 + M50_54 + M55_59 + M60_64 + M65')
print(male_perpetrators)
# Out:
#        GROUP  DIV CORE  STNAME  OFFENSE  M0_9  M10_12  M13_14  M15  M16  ...  \
# 1         1C    9    Y  ALASKA       20     0       0       0    1    0  ...
# 15        1C    9    Y  ALASKA      170     0       1       3    0    2  ...
# 33         4    9    Y  ALASKA       20     0       0       3    1    0  ...
# 47         4    9    Y  ALASKA      170     0       0       0    0    0  ...
# 63         4    9    N  ALASKA       20     0       0       1    0    0  ...
# ...      ...  ...  ...     ...      ...   ...     ...     ...  ...  ...  ...
# 259176    8C    8    N     WYO      170     0       0       0    0    0  ...
# 259192     6    8    N     WYO       20     0       0       0    0    0  ...
# 259203     6    8    N     WYO      170     0       0       0    0    0  ...
# 259227    8D    8    N     WYO      170     0       0       0    0    0  ...
# 259250     5    8    N     WYO      170     0       0       0    0    0  ...
#
# ...

# %%
female_perpetrators = sexual_violence_US.eval('Female_Sum = F0_9 + F10_12 + F13_14 + F15 + F16 + F17 + F18 + F19 + F20 + F21 + F22 + F23 + F24 + F25_29 + F30_34 + F35_39 + F40_44 + F45_49 + F50_54 + F55_59 + F60_64 + F65')
print(female_perpetrators)
# Out:
#        GROUP  DIV CORE  STNAME  OFFENSE  M0_9  M10_12  M13_14  M15  M16  ...  \
# 1         1C    9    Y  ALASKA       20     0       0       0    1    0  ...
# 15        1C    9    Y  ALASKA      170     0       1       3    0    2  ...
# 33         4    9    Y  ALASKA       20     0       0       3    1    0  ...
# 47         4    9    Y  ALASKA      170     0       0       0    0    0  ...
# 63         4    9    N  ALASKA       20     0       0       1    0    0  ...
# ...      ...  ...  ...     ...      ...   ...     ...     ...  ...  ...  ...
# 259176    8C    8    N     WYO      170     0       0       0    0    0  ...
# 259192     6    8    N     WYO       20     0       0       0    0    0  ...
# 259203     6    8    N     WYO      170     0       0       0    0    0  ...
# 259227    8D    8    N     WYO      170     0       0       0    0    0  ...
# 259250     5    8    N     WYO      170     0       0       0    0    0  ...
#
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
male_perpetrators_gb = male_perpetrators.groupby('STNAME', as_index=False).sum()
display(male_perpetrators_gb)
# Out:
#     STNAME   DIV  OFFENSE  M0_9  M10_12  M13_14  M15  M16  M17  M18  ...  JA  \
# 0      ALA  1146    18820     0       1       4    4    9   11   41  ...   0
# 1   ALASKA   225     2900    20       3      13    5    7   10    9  ...   2
# 2     ARIZ   872    13580     7      43     109   57   59   60   65  ...   4
# 3      ARK  1064    13540     0      14      28    7   11   12   21  ...   0
# 4    CALIF  8163   103190    28     220     732  423  472  451  489  ...  28
# 5     COLO  1640    22100     1      91     154   62   47   46   47  ...   7
# 6     CONN   123    14910     2      21      55   45   51   49   73  ...   2
# 7      D C     5      170     0       0       0    0    0    1    1  ...   0
# 8      DEL   200     3650     1      12      39   15   11    8    9  ...   0
# 9       GA  1600    37750    23      85     168   72   85  143  191  ...   0
# 10  HAWAII    72      760     0      10      25    9   10    7   15  ...  40
# ...

# %%
states = {
        'ALA': 'Alabama',
        'ALASKA': 'Alaska',
        'ARK': 'Arkansas',
        'ARIZ': 'Arizona',
        'CALIF': 'California',
        'COLO': 'Colorado',
        'CONN': 'Connecticut',
        'D C': 'District of Columbia',
        'DEL': 'Delaware',
        'HAWAII': 'Hawaii',
        'GA': 'Georgia',
        'ILL': 'Illinois',
        'IDAHO': 'Idaho',
        'IND': 'Indiana',
        'IOWA': 'Iowa',
        'KANS': 'Kansas',
        'KY': 'Kentucky',
        'LA': 'Louisiana',
        'MAINE': 'Maine',
        'MASS': 'Massachusetts',
        'MD': 'Maryland',
        'MICH': 'Michigan',
        'MINN': 'Minnesota',
        'MISS': 'Mississippi',
        'MO': 'Missouri',
        'MONT': 'Montana',
        'N C': 'North Carolina',
        'N DAK': 'North Dakota',
        'N H': 'New Hampshire',
        'N J': 'New Jersey',
        'N MEX': 'New Mexico',
        'N Y': 'New York',
        'NEBR': 'Nebraska',
        'NEV': 'Nevada',
        'OKLA': 'Oklahoma',
        'OHIO': 'Ohio',
        'OREG': 'Oregon',
        'PA': 'Pennsylvania',
        'R I': 'Rhode Island',
        'S C': 'South Carolina',
        'S DAK': 'South Dakota',
        'TENN': 'Tennessee',
        'TEXAS': 'Texas',
        'VA': 'Virginia',
        'VT': 'Vermont',
        'W VA': 'West Virginia',
        'UTAH': 'Utah',
        'WASH': 'Washington',
        'WIS': 'Wisonsin',
        'WYO': 'Wyoming'}

# %%
male_perpetrators_gb['STNAME'] = male_perpetrators_gb['STNAME'].replace(states)
male_perpetrators_gb.head()
# Out:
#        STNAME   DIV  OFFENSE  M0_9  M10_12  M13_14  M15  M16  M17  M18  ...  \
# 0     Alabama  1146    18820     0       1       4    4    9   11   41  ...
# 1      Alaska   225     2900    20       3      13    5    7   10    9  ...
# 2     Arizona   872    13580     7      43     109   57   59   60   65  ...
# 3    Arkansas  1064    13540     0      14      28    7   11   12   21  ...
# 4  California  8163   103190    28     220     732  423  472  451  489  ...
#
#    JA  JH  JN     AW    AB   AI   AA  AH  AN  Male_Sum
# 0   0   0   0    436   337    5    3   0   0       796
# 1   2   0   0    110     6   99    4   0   0       274
# 2   4   0   0   1358   124  124    7   0   0      1871
# 3   0   0   0    388   131    1    4   0   0       582
# 4  28   0   0  11520  3099   83  151   0   0     15492
#
# [5 rows x 60 columns]

# %%
male_perpetrators_gb.plot.bar(x='STNAME', y='Male_Sum')
# Out:
# <AxesSubplot:xlabel='STNAME'>

# %%
female_perpetrators_gb = female_perpetrators.groupby('STNAME', as_index=False).sum()
display(female_perpetrators_gb)
# Out:
#     STNAME   DIV  OFFENSE  M0_9  M10_12  M13_14  M15  M16  M17  M18  ...  JA  \
# 0      ALA  1146    18820     0       1       4    4    9   11   41  ...   0
# 1   ALASKA   225     2900    20       3      13    5    7   10    9  ...   2
# 2     ARIZ   872    13580     7      43     109   57   59   60   65  ...   4
# 3      ARK  1064    13540     0      14      28    7   11   12   21  ...   0
# 4    CALIF  8163   103190    28     220     732  423  472  451  489  ...  28
# 5     COLO  1640    22100     1      91     154   62   47   46   47  ...   7
# 6     CONN   123    14910     2      21      55   45   51   49   73  ...   2
# 7      D C     5      170     0       0       0    0    0    1    1  ...   0
# 8      DEL   200     3650     1      12      39   15   11    8    9  ...   0
# 9       GA  1600    37750    23      85     168   72   85  143  191  ...   0
# 10  HAWAII    72      760     0      10      25    9   10    7   15  ...  40
# ...

# %%
states = {
        'ALA': 'Alabama',
        'ALASKA': 'Alaska',
        'ARK': 'Arkansas',
        'ARIZ': 'Arizona',
        'CALIF': 'California',
        'COLO': 'Colorado',
        'CONN': 'Connecticut',
        'D C': 'District of Columbia',
        'DEL': 'Delaware',
        'HAWAII': 'Hawaii',
        'GA': 'Georgia',
        'ILL': 'Illinois',
        'IDAHO': 'Idaho',
        'IND': 'Indiana',
        'IOWA': 'Iowa',
        'KANS': 'Kansas',
        'KY': 'Kentucky',
        'LA': 'Louisiana',
        'MAINE': 'Maine',
        'MASS': 'Massachusetts',
        'MD': 'Maryland',
        'MICH': 'Michigan',
        'MINN': 'Minnesota',
        'MISS': 'Mississippi',
        'MO': 'Missouri',
        'MONT': 'Montana',
        'N C': 'North Carolina',
        'N DAK': 'North Dakota',
        'N H': 'New Hampshire',
        'N J': 'New Jersey',
        'N MEX': 'New Mexico',
        'N Y': 'New York',
        'NEBR': 'Nebraska',
        'NEV': 'Nevada',
        'OKLA': 'Oklahoma',
        'OHIO': 'Ohio',
        'OREG': 'Oregon',
        'PA': 'Pennsylvania',
        'R I': 'Rhode Island',
        'S C': 'South Carolina',
        'S DAK': 'South Dakota',
        'TENN': 'Tennessee',
        'TEXAS': 'Texas',
        'VA': 'Virginia',
        'VT': 'Vermont',
        'W VA': 'West Virginia',
        'UTAH': 'Utah',
        'WASH': 'Washington',
        'WIS': 'Wisonsin',
        'WYO': 'Wyoming'}

# %%
female_perpetrators_gb['STNAME'] = female_perpetrators_gb['STNAME'].replace(states)
female_perpetrators_gb.head()
# Out:
#        STNAME   DIV  OFFENSE  M0_9  M10_12  M13_14  M15  M16  M17  M18  ...  \
# 0     Alabama  1146    18820     0       1       4    4    9   11   41  ...
# 1      Alaska   225     2900    20       3      13    5    7   10    9  ...
# 2     Arizona   872    13580     7      43     109   57   59   60   65  ...
# 3    Arkansas  1064    13540     0      14      28    7   11   12   21  ...
# 4  California  8163   103190    28     220     732  423  472  451  489  ...
#
#    JA  JH  JN     AW    AB   AI   AA  AH  AN  Female_Sum
# 0   0   0   0    436   337    5    3   0   0          18
# 1   2   0   0    110     6   99    4   0   0           6
# 2   4   0   0   1358   124  124    7   0   0          99
# 3   0   0   0    388   131    1    4   0   0          21
# 4  28   0   0  11520  3099   83  151   0   0        2022
#
# [5 rows x 60 columns]

# %%
female_perpetrators_gb.plot.bar(x='STNAME', y='Female_Sum')
# Out:
# <AxesSubplot:xlabel='STNAME'>

# %%
population_df=pd.read_csv('population_2005.csv')
population_df.head(10)
# Out:
#    Selected Geographies      Total       Male     Female
# 0              -> Total  288398819  141363811  147035008
# 1               Alabama    4448075    2147657    2300418
# 2                Alaska     658002     334799     323203
# 3               Arizona    5806266    2902590    2903676
# 4              Arkansas    2694665    1320930    1373735
# 5            California   35340566   17541652   17798914
# 6              Colorado    4540639    2276177    2264462
# 7           Connecticut    3365768    1636455    1729313
# 8              Delaware     825598     403999     421599
# 9  District of Columbia     508572     238733     269839

# %%
males_merged = male_perpetrators_gb.merge(population_df, left_on='STNAME', right_on='Selected Geographies')
males_merged.head()
# Out:
#        STNAME   DIV  OFFENSE  M0_9  M10_12  M13_14  M15  M16  M17  M18  ...  \
# 0     Alabama  1146    18820     0       1       4    4    9   11   41  ...
# 1      Alaska   225     2900    20       3      13    5    7   10    9  ...
# 2     Arizona   872    13580     7      43     109   57   59   60   65  ...
# 3    Arkansas  1064    13540     0      14      28    7   11   12   21  ...
# 4  California  8163   103190    28     220     732  423  472  451  489  ...
#
#      AB   AI   AA  AH  AN  Male_Sum  Selected Geographies     Total      Male  \
# 0   337    5    3   0   0       796               Alabama   4448075   2147657
# 1     6   99    4   0   0       274                Alaska    658002    334799
# 2   124  124    7   0   0      1871               Arizona   5806266   2902590
# 3   131    1    4   0   0       582              Arkansas   2694665   1320930
# 4  3099   83  151   0   0     15492            California  35340566  17541652
#
#      Female
# 0   2300418
# 1    323203
# ...

# %%
males_merged['male_perpetrators_per_capita'] = males_merged['Male_Sum'] / males_merged['Male']
males_merged.head()
# Out:
#        STNAME   DIV  OFFENSE  M0_9  M10_12  M13_14  M15  M16  M17  M18  ...  \
# 0     Alabama  1146    18820     0       1       4    4    9   11   41  ...
# 1      Alaska   225     2900    20       3      13    5    7   10    9  ...
# 2     Arizona   872    13580     7      43     109   57   59   60   65  ...
# 3    Arkansas  1064    13540     0      14      28    7   11   12   21  ...
# 4  California  8163   103190    28     220     732  423  472  451  489  ...
#
#     AI   AA  AH  AN  Male_Sum  Selected Geographies     Total      Male  \
# 0    5    3   0   0       796               Alabama   4448075   2147657
# 1   99    4   0   0       274                Alaska    658002    334799
# 2  124    7   0   0      1871               Arizona   5806266   2902590
# 3    1    4   0   0       582              Arkansas   2694665   1320930
# 4   83  151   0   0     15492            California  35340566  17541652
#
#      Female  male_perpetrators_per_capita
# ...

# %%
males_merged['male_perpetrators_per_100k_people'] = males_merged['Male_Sum'] / males_merged['Male'] * 100000
males_merged.head(55)
# Out:
#                   STNAME   DIV  OFFENSE  M0_9  M10_12  M13_14  M15  M16  M17  \
# 0                Alabama  1146    18820     0       1       4    4    9   11
# 1                 Alaska   225     2900    20       3      13    5    7   10
# 2                Arizona   872    13580     7      43     109   57   59   60
# 3               Arkansas  1064    13540     0      14      28    7   11   12
# 4             California  8163   103190    28     220     732  423  472  451
# 5               Colorado  1640    22100     1      91     154   62   47   46
# 6            Connecticut   123    14910     2      21      55   45   51   49
# 7   District of Columbia     5      170     0       0       0    0    0    1
# 8               Delaware   200     3650     1      12      39   15   11    8
# 9                Georgia  1600    37750    23      85     168   72   85  143
# 10                Hawaii    72      760     0      10      25    9   10    7
# ...

# %%
males_merged.plot.bar(x='STNAME', y='male_perpetrators_per_100k_people')
plt.tight_layout()
plt.ylim(ymin=0, ymax=150)
plt.xlabel('State')
plt.ylabel('Male Arrests per 100k People')
plt.legend().remove()
plt.title('Male Arrests for Sexual Violence by State, 2005')
# Out:
# Text(0.5, 1.0, 'Male Arrests for Sexual Violence by State, 2005')

# %%
females_merged = female_perpetrators_gb.merge(population_df, left_on='STNAME', right_on='Selected Geographies')
females_merged.head()
# Out:
#        STNAME   DIV  OFFENSE  M0_9  M10_12  M13_14  M15  M16  M17  M18  ...  \
# 0     Alabama  1146    18820     0       1       4    4    9   11   41  ...
# 1      Alaska   225     2900    20       3      13    5    7   10    9  ...
# 2     Arizona   872    13580     7      43     109   57   59   60   65  ...
# 3    Arkansas  1064    13540     0      14      28    7   11   12   21  ...
# 4  California  8163   103190    28     220     732  423  472  451  489  ...
#
#      AB   AI   AA  AH  AN  Female_Sum  Selected Geographies     Total  \
# 0   337    5    3   0   0          18               Alabama   4448075
# 1     6   99    4   0   0           6                Alaska    658002
# 2   124  124    7   0   0          99               Arizona   5806266
# 3   131    1    4   0   0          21              Arkansas   2694665
# 4  3099   83  151   0   0        2022            California  35340566
#
#        Male    Female
# 0   2147657   2300418
# 1    334799    323203
# ...

# %%
females_merged['female_perpetrators_per_capita'] = females_merged['Female_Sum'] / females_merged['Female']
females_merged.head()
# Out:
#        STNAME   DIV  OFFENSE  M0_9  M10_12  M13_14  M15  M16  M17  M18  ...  \
# 0     Alabama  1146    18820     0       1       4    4    9   11   41  ...
# 1      Alaska   225     2900    20       3      13    5    7   10    9  ...
# 2     Arizona   872    13580     7      43     109   57   59   60   65  ...
# 3    Arkansas  1064    13540     0      14      28    7   11   12   21  ...
# 4  California  8163   103190    28     220     732  423  472  451  489  ...
#
#     AI   AA  AH  AN  Female_Sum  Selected Geographies     Total      Male  \
# 0    5    3   0   0          18               Alabama   4448075   2147657
# 1   99    4   0   0           6                Alaska    658002    334799
# 2  124    7   0   0          99               Arizona   5806266   2902590
# 3    1    4   0   0          21              Arkansas   2694665   1320930
# 4   83  151   0   0        2022            California  35340566  17541652
#
#      Female  female_perpetrators_per_capita
# ...

# %%
females_merged['female_perpetrators_per_100k_people'] = females_merged['Female_Sum'] / females_merged['Female'] * 100000
females_merged.head()
# Out:
#        STNAME   DIV  OFFENSE  M0_9  M10_12  M13_14  M15  M16  M17  M18  ...  \
# 0     Alabama  1146    18820     0       1       4    4    9   11   41  ...
# 1      Alaska   225     2900    20       3      13    5    7   10    9  ...
# 2     Arizona   872    13580     7      43     109   57   59   60   65  ...
# 3    Arkansas  1064    13540     0      14      28    7   11   12   21  ...
# 4  California  8163   103190    28     220     732  423  472  451  489  ...
#
#     AA  AH  AN  Female_Sum  Selected Geographies     Total      Male  \
# 0    3   0   0          18               Alabama   4448075   2147657
# 1    4   0   0           6                Alaska    658002    334799
# 2    7   0   0          99               Arizona   5806266   2902590
# 3    4   0   0          21              Arkansas   2694665   1320930
# 4  151   0   0        2022            California  35340566  17541652
#
#      Female  female_perpetrators_per_capita  \
# 0   2300418                        0.000008
# ...

# %%
females_merged.plot.bar(x='STNAME', y='female_perpetrators_per_100k_people')
plt.tight_layout() 
plt.ylim(ymin=0, ymax=15)
plt.xlabel('State')
plt.ylabel('Female Arrests per 100k People')
plt.legend().remove()
plt.title('Female Arrests for Sexual Violence by State, 2005')
# Out:
# Text(0.5, 1.0, 'Female Arrests for Sexual Violence by State, 2005')

# %%
#TO DO: Make a map out of this data?????
