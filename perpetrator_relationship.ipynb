# %%
import pandas as pd

# %%
perpetrator_relationship_df=pd.read_csv('perpetrator-relationship.csv')

# %%
perpetrator_relationship_df.head(20)
# Out:
#           Offender characteristic   Unnamed: 1  \
# 0             Number of offenders          NaN
# 1                             NaN          One
# 2                             NaN  Two or more
# 3  Victim-offender relationship/a          NaN
# 4                             NaN     Stranger
# 5                             NaN  Nonstranger
# 6                             NaN          NaN
# 7                             NaN          NaN
# 8                             NaN          NaN
#
#                        Unnamed: 2  1994 to 1998 Unnamed: 4  1999 to 2004  \
# 0                             NaN           100        100           100
# 1                             NaN            93        NaN            91
# 2                             NaN             7                        9
# 3                             NaN           100        100           100
# 4                             NaN            21        NaN            25
# 5                             NaN            79        NaN            75
# 6              Intimate partner/b            28                       30
# 7                        Relative             9                        3
# 8  Well-known/casual acquaintance            42                       42
#
#   Unnamed: 6  2005 to 2010 Unnamed: 8
# 0        NaN           NaN        NaN
# 1        NaN          90.0        NaN
# 2                     10.0        NaN
# 3        NaN           NaN        NaN
# 4        NaN          22.0        NaN
# 5        NaN          78.0        NaN
# 6                     34.0
# 7                      6.0
# 8                     38.0
